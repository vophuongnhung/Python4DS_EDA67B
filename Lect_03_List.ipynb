# %% [markdown]
# ## Lecture 3: List

# %% [markdown]
# **3-1. Names**: Store the names of a few of your friends in a list called names. Print
# each person’s name by accessing each element in the list, one at a time.

# %%
# ID: 12313131, Fullname: Nguyen Tuan Long

# %% [markdown]
# **3-2. Greetings:** Start with the list you used in Exercise 3-1, but instead of just
# printing each person’s name, print a message to them. The text of each message should be the same, but each message should be personalized with the
# person’s name.

# %% [markdown]
# **3-3. Your Own List:** Think of your favorite mode of transportation, such as a
# motorcycle or a car, and make a list that stores several examples. Use your list
# to print a series of statements about these items, such as “I would like to own a
# Honda motorcycle.

# %%
bool([])
# Out:
# False

# %%
bool([1])
# Out:
# True

# %%
alist = [1,2,2,3,1,3,3]
alist.remove(1)
alist
# Out:
# [2, 2, 3, 1, 3, 3]

# %%
dir(alist)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
alist
# Out:
# [2, 2, 3, 1, 3, 3]

# %%
alist.count(2)
# Out:
# 2

# %%
alist.count(3)
# Out:
# 3

# %%
alist.remove(3)
alist.remove(3)
alist.remove(3)
alist
# Out:
# [2, 2, 1]

# %%
digits = [2,3,10,4,5,4,5,45,4,2]
digits.sort()
digits
# Out:
# [2, 2, 3, 4, 4, 4, 5, 5, 10, 45]

# %%
digits = [2,3,10,4,5,4,5,45,4,2]
digits.sort(reverse=True)
digits
# Out:
# [45, 10, 5, 5, 4, 4, 4, 3, 2, 2]

# %%
alist = [1,2,'afc', [1,2]]
alist.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 alist = [1,2,'afc', [1,2]]
# ----> 2 alist.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
alist = ["1","2",'afc', [1,2]]
alist.sort()
alist
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 alist = ["1","2",'afc', [1,2]]
# ----> 2 alist.sort()
#       3 alist
#
# TypeError: '<' not supported between instances of 'list' and 'str'

# %%
alist = ["1","2",'afc', [1,2]]
alist.sort(key=lambda x:len(x))
alist
# Out:
# ['1', '2', [1, 2], 'afc']

# %%
scores = [['An', 8],['Mai', 7], ['Anh', 10], ['Hà', 5]]

# %%
sorted(scores)
# Out:
# [['An', 8], ['Anh', 10], ['Hà', 5], ['Mai', 7]]

# %%
sorted(scores, key=lambda x: x[1], reverse= True)
# Out:
# [['Anh', 10], ['An', 8], ['Mai', 7], ['Hà', 5]]

# %% [markdown]
# **3-8. Seeing the World**: Think of at least five places in the world you’d like to
# visit.
#
# + Store the locations in a list. Make sure the list is not in alphabetical order.
# + Print your list in its original order. Don’t worry about printing the list neatly, just print it as a raw Python list.
# +  Use sorted() to print your list in alphabetical order without modifying the
# actual list.
# + Show that your list is still in its original order by printing it.
# + Use sorted() to print your list in reverse alphabetical order without changing the order of the original list.
# + Show that your list is still in its original order by printing it again.
# + Use reverse() to change the order of your list. Print the list to show that its
# order has changed.
# + Use reverse() to change the order of your list again. Print the list to show
# it’s back to its original order.
# + Use sort() to change your list so it’s stored in alphabetical order. Print the
# list to show that its order has been changed.
# + Use sort() to change your list so it’s stored in reverse alphabetical order.
# Print the list to show that its order has changed.

# %% [markdown]
# 3-9. Dinner Guests: Working with one of the programs from Exercises 3-4
# through 3-7 (page 42), use len() to print a message indicating the number
# of people you are inviting to dinner.
# 3-10. Every Function: Think of something you could store in a list. For example,
# you could make a list of mountains, rivers, countries, cities, languages, or anything else you’d like. Write a program that creates a list containing these items
# and then uses each function introduced in this chapter at least once.

# %%
dir(digits)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
digits
# Out:
# [45, 10, 5, 5, 4, 4, 4, 3, 2, 2]

# %%
digits.count(5)
# Out:
# 2

# %%
digits.count(4)
# Out:
# 3

# %%
scores
# Out:
# [['An', 8], ['Mai', 7], ['Anh', 10], ['Hà', 5]]

# %%
scores = [['An', 8], ['Mai', 7], ['Anh', 10], ['Hà', 5]]
s = 0
for score in scores:
    s += score[1]
s/len(scores)
# Out:
# 7.5

# %%
type(range(1,4))
# Out:
# range

# %%
list(range(3,10))
# Out:
# [3, 4, 5, 6, 7, 8, 9]

# %%
list(range(4)) #start = 0
# Out:
# [0, 1, 2, 3]

# %%
list(range(2,9,3)) #default step = 1
# Out:
# [2, 5, 8]

# %%
squares = []
for i in range(1,11):
    squares.append(i**2)
squares
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
for i in range(0,100,7):
    print(i**2)
# Out:
# 0
# 49
# 196
# 441
# 784
# 1225
# 1764
# 2401
# 3136
# 3969
# 4900
# 5929
# 7056
# 8281
# 9604

# %%
digits.sort()
digits
# Out:
# [2, 2, 3, 4, 4, 4, 5, 5, 10, 45]

# %%
digits = list(range(1,10))
print(digits)
n = len(digits)
mid = n//2 
median = (n%2==0)*(digits[mid]+digits[mid-1])/2 +(n%2==1)*(digits[mid])
print(median)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 5.0

# %%
squares_10 = [i**2 for i in range(1,11) # if statement]
squares_10
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
True*9
# Out:
# 9

# %%
alist = [1,2]
print(alist)
blist = alist
blist.append('new')
print(alist)
print(blist)
# Out:
# [1, 2]
# [1, 2, 'new']
# [1, 2, 'new']

# %%
alist = [1,2]
print(alist)
blist = alist[:] #slicing as copy
blist.append('new')
print(alist)
print(blist)
# Out:
# [1, 2]
# [1, 2]
# [1, 2, 'new']

# %%
# shalow copy and deep copy
alist = [1,[2,1]]
print(alist)
blist = alist[:] #slicing as copy
blist[1][1] = 'new'
print(alist)
print(blist)
# Out:
# [1, [2, 1]]
# [1, [2, 'new']]
# [1, [2, 'new']]

# %%
atuple = (i for i in range(10))
print(atuple)
# Out:
# <generator object <genexpr> at 0x000001D0F903A740>

# %%
type(atuple)
# Out:
# generator

# %%
digits = (1,3,4,2,1,6)

# %%
type(digits)
# Out:
# tuple

# %%
digits[1]
# Out:
# 3

# %%
digits[1:3]
# Out:
# (3, 4)

# %%
digits.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 digits.sort()
#
# AttributeError: 'tuple' object has no attribute 'sort'

# %%
sorted(digits)
# Out:
# [1, 1, 2, 3, 4, 6]

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
text = """ 
The Zen of Python, by Tim Peters

Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!
"""

# %%
#normalization
text_norm = text.lower()
special_chars = {',','.','*',':','-','!'}
for char in special_chars:
    text_norm = text_norm.replace(char,' ')
print(text_norm)
# Out:
#
# the zen of python  by tim peters
#
# beautiful is better than ugly
# explicit is better than implicit
# simple is better than complex
# complex is better than complicated
# flat is better than nested
# sparse is better than dense
# readability counts
# special cases aren't special enough to break the rules
# although practicality beats purity
# errors should never pass silently
# unless explicitly silenced
# in the face of ambiguity  refuse the temptation to guess
# there should be one   and preferably only one   obvious way to do it
# although that way may not be obvious at first unless you're dutch
# now is better than never
# although never is often better than  right  now
# if the implementation is hard to explain  it's a bad idea
# if the implementation is easy to explain  it may be a good idea
# namespaces are one honking great idea    let's do more of those

# %%
len(text_norm) - text_norm.count(' ') -text_norm.count('\n')
# Out:
# 681

# %%
len(set(text_norm)-{'\n',' ',"'"})
# Out:
# 24

# %%
text_norm.split().count('the')
# Out:
# 6

# %%
#fre_words = [(word,fre),....]
words = text_norm.split()
unique_words = set(words) 
fre_words = []
for w in unique_words:
    fre_words.append((w,words.count(w)))

# %%
fre_words
# Out:
# [('enough', 1),
#  ('preferably', 1),
#  ('namespaces', 1),
#  ('silently', 1),
#  ('tim', 1),
#  ('right', 1),
#  ('explain', 2),
#  ('should', 2),
#  ('is', 10),
#  ('beautiful', 1),
#  ('hard', 1),
#  ('counts', 1),
#  ('zen', 1),
#  ('in', 1),
#  ('complex', 2),
#  ('than', 8),
#  ('good', 1),
#  ('practicality', 1),
#  ('one', 3),
#  ('those', 1),
#  ('better', 8),
#  ('there', 1),
#  ('nested', 1),
#  ('flat', 1),
#  ('way', 2),
#  ("aren't", 1),
#  ('implicit', 1),
#  ('guess', 1),
#  ('and', 1),
#  ('explicit', 1),
#  ('at', 1),
#  ('dense', 1),
#  ('temptation', 1),
#  ('idea', 3),
#  ('break', 1),
#  ('may', 2),
#  ('not', 1),
#  ('readability', 1),
#  ('dutch', 1),
#  ('obvious', 2),
#  ('more', 1),
#  ('easy', 1),
#  ('pass', 1),
#  ("it's", 1),
#  ('python', 1),
#  ('although', 3),
#  ('complicated', 1),
#  ('explicitly', 1),
#  ('unless', 2),
#  ('of', 3),
#  ('great', 1),
#  ('silenced', 1),
#  ('the', 6),
#  ('ambiguity', 1),
#  ('now', 2),
#  ('first', 1),
# ...

# %%
len(words)
# Out:
# 143

# %%
len(unique_words)
# Out:
# 85

# %%
sorted(fre_words,key=lambda x: x[1], reverse=True)
# Out:
# [('is', 10),
#  ('than', 8),
#  ('better', 8),
#  ('the', 6),
#  ('to', 5),
#  ('one', 3),
#  ('idea', 3),
#  ('although', 3),
#  ('of', 3),
#  ('be', 3),
#  ('never', 3),
#  ('explain', 2),
#  ('should', 2),
#  ('complex', 2),
#  ('way', 2),
#  ('may', 2),
#  ('obvious', 2),
#  ('unless', 2),
#  ('now', 2),
#  ('if', 2),
#  ('a', 2),
#  ('it', 2),
#  ('special', 2),
#  ('do', 2),
#  ('implementation', 2),
#  ('enough', 1),
#  ('preferably', 1),
#  ('namespaces', 1),
#  ('silently', 1),
#  ('tim', 1),
#  ('right', 1),
#  ('beautiful', 1),
#  ('hard', 1),
#  ('counts', 1),
#  ('zen', 1),
#  ('in', 1),
#  ('good', 1),
#  ('practicality', 1),
#  ('those', 1),
#  ('there', 1),
#  ('nested', 1),
#  ('flat', 1),
#  ("aren't", 1),
#  ('implicit', 1),
#  ('guess', 1),
#  ('and', 1),
#  ('explicit', 1),
#  ('at', 1),
#  ('dense', 1),
#  ('temptation', 1),
#  ('break', 1),
#  ('not', 1),
#  ('readability', 1),
#  ('dutch', 1),
#  ('more', 1),
#  ('easy', 1),
#  ('pass', 1),
#  ("it's", 1),
# ...
