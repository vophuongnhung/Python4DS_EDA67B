# %% [markdown]
# ## Lecture 06: Dictionay

# %%
scores = {'Lan':9, 'Mai':10, 'Hoa':7, "Minh":4}

# %%
scores['Lan']
# Out:
# 9

# %%
scores['Lan'] = 9.5
scores
# Out:
# {'Lan': 9.5, 'Mai': 10, 'Hoa': 7, 'Minh': 4}

# %%
scores['Hoang'] = 6
scores
# Out:
# {'Lan': 9.5, 'Mai': 10, 'Hoa': 7, 'Minh': 4, 'Hoang': 6}

# %%
scores['Mai'] = 7.5
scores
# Out:
# {'Lan': 9.5, 'Mai': 7.5, 'Hoa': 7, 'Minh': 4, 'Hoang': 6}

# %%
{'Lan': 9.5, 'Mai': 10, 'Hoa': 7, 'Minh': 4, 'Hoang': 6, "Mai":8.5}
# Out:
# {'Lan': 9.5, 'Mai': 8.5, 'Hoa': 7, 'Minh': 4, 'Hoang': 6}

# %%
{'Lan': 9.5, 'Mai': 10, 'Hoa': 7, 'Minh': 4, 'Hoang': 6, ["Mai",'Minh']:8.5}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 {'Lan': 9.5, 'Mai': 10, 'Hoa': 7, 'Minh': 4, 'Hoang': 6, ["Mai",'Minh']:8.5}
#
# TypeError: unhashable type: 'list'

# %%
{'Lan': 9.5, 'Mai': 10, 'Hoa': 7, 'Minh': 4, 'Hoang': 6, ("Mai",'Minh'):8.5}
# Out:
# {'Lan': 9.5, 'Mai': 10, 'Hoa': 7, 'Minh': 4, 'Hoang': 6, ('Mai', 'Minh'): 8.5}

# %%
{'Lan': 9.5, 'Mai': 10, 'Hoa': [7,9]}
# Out:
# {'Lan': 9.5, 'Mai': 10, 'Hoa': [7, 9]}

# %%
scores
# Out:
# {'Lan': 9.5, 'Mai': 7.5, 'Hoa': 7, 'Minh': 4, 'Hoang': 6}

# %%
del scores['Hoang']
scores
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 del scores['Hoang']
#       2 scores
#
# KeyError: 'Hoang'

# %%
dir(scores)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
scores = {'Lan': 9.5, 'Mai': 7.5, 'Hoa': 7, 'Minh': 4}
scores.clear()
scores
# Out:
# {}

# %%
scores = {'Lan': 9.5, 'Mai': 7.5, 'Hoa': 7, 'Minh': 4}
scores.pop('Minh')
scores
# Out:
# {'Lan': 9.5, 'Mai': 7.5, 'Hoa': 7}

# %%
scores = {'Lan': 9.5, 'Mai': 7.5, 'Hoa': 7, 'Minh': 4}
scores.popitem()
scores
# Out:
# {'Lan': 9.5, 'Mai': 7.5, 'Hoa': 7}

# %%
scores['Minh']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 scores['Minh']
#
# KeyError: 'Minh'

# %%
scores.get('Minh', 'the key is not availible')
# Out:
# 'the key is not availible'

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
text = '''The Zen of Python, by Tim Peters

Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!'''

# %%
text = text.lower()
for char in {'.', '.','?',"*",'-'}:
    text  = text.replace(char,' ')
words = text.split()
fre_words = {} # = dict()
for w in words:
    if w in fre_words:
        fre_words[w] += 1
    else: 
        fre_words[w] = 1
fre_words
# Out:
# {'the': 6,
#  'zen': 1,
#  'of': 3,
#  'python,': 1,
#  'by': 1,
#  'tim': 1,
#  'peters': 1,
#  'beautiful': 1,
#  'is': 10,
#  'better': 8,
#  'than': 8,
#  'ugly': 1,
#  'explicit': 1,
#  'implicit': 1,
#  'simple': 1,
#  'complex': 2,
#  'complicated': 1,
#  'flat': 1,
#  'nested': 1,
#  'sparse': 1,
#  'dense': 1,
#  'readability': 1,
#  'counts': 1,
#  'special': 2,
#  'cases': 1,
#  "aren't": 1,
#  'enough': 1,
#  'to': 5,
#  'break': 1,
#  'rules': 1,
#  'although': 3,
#  'practicality': 1,
#  'beats': 1,
#  'purity': 1,
#  'errors': 1,
#  'should': 2,
#  'never': 3,
#  'pass': 1,
#  'silently': 1,
#  'unless': 2,
#  'explicitly': 1,
#  'silenced': 1,
#  'in': 1,
#  'face': 1,
#  'ambiguity,': 1,
#  'refuse': 1,
#  'temptation': 1,
#  'guess': 1,
#  'there': 1,
#  'be': 3,
#  'one': 3,
#  'and': 1,
#  'preferably': 1,
#  'only': 1,
#  'obvious': 2,
#  'way': 2,
#  'do': 2,
#  'it': 2,
#  'that': 1,
#  'may': 2,
#  'not': 1,
#  'at': 1,
#  'first': 1,
#  "you're": 1,
# ...

# %%
scores
# Out:
# {'Lan': 9.5, 'Mai': 7.5, 'Hoa': 7}

# %%
scores.items()
# Out:
# dict_items([('Lan', 9.5), ('Mai', 7.5), ('Hoa', 7)])

# %%
for key, val in scores.items():
    print(key, val)
# Out:
# Lan 9.5
# Mai 7.5
# Hoa 7

# %%
fre = [('Lan', 9.5), ('Mai', 7.5), ('Hoa', 7)]
type(fre)
# Out:
# list

# %%
dict(fre)
# Out:
# {'Lan': 9.5, 'Mai': 7.5, 'Hoa': 7}

# %%
scores.keys()
# Out:
# dict_keys(['Lan', 'Mai', 'Hoa'])

# %%
scores.values()
# Out:
# dict_values([9.5, 7.5, 7])

# %%
list(zip(scores.keys(),scores.values()))
# Out:
# [('Lan', 9.5), ('Mai', 7.5), ('Hoa', 7)]

# %%
for key in scores.keys():
    print(key, scores[key])
# Out:
# Lan 9.5
# Mai 7.5
# Hoa 7

# %%
for val in scores.values():
    print(val)
# Out:
# 9.5
# 7.5
# 7

# %%
for key in scores:
    print(key, scores[key])
# Out:
# Lan 9.5
# Mai 7.5
# Hoa 7

# %%
scores
# Out:
# {'Lan': 9.5, 'Mai': 7.5, 'Hoa': 7}

# %%
'Lan' in scores.keys()
# Out:
# True

# %%
'Lan' in scores
# Out:
# True
