# %% [markdown]
# #**I. Multiple Choice**

# %% [markdown]
# **1. What is the correct file extension for a Jupyter Notebook file?**
# A. .py
# B. .jup
# C. .ipynb
# D. .note
#
# **2. What is the default data type returned by the input() function?**
# A. Integer (int)
# B. Float (float)
# C. String (str)
# D. Boolean (bool)
#
# **3. In Markdown, how do you make a text bold?**
# A. `*text*`
# B. `**text**`
# C. `#text#`
# D. `~~text~~`
#
# **4. Which operator is used to find the remainder of a division in Python?**
# A. //
# B. /
# C. **
# D. %
#
# **5. If greeting = "Hello World", which code will output "HELLO WORLD"?**
# A. `print(greeting.title())`
# B. `print(greeting.upper())`
# C. `print(upper(greeting))`
# D. `print(greeting.capitalize())`
#
# **6. What will be the output of print(int(1.9))?**
# A. 1.9
# B. 2
# C. 1
# D. Error
#
# **7. What is the output of the following Python code: `print("Python", "Easy", sep="\n", end="!")`?**
# A. Python<br>
# &emsp;&nbsp;Easy!
#
# B. Python!<br>
# &emsp;&nbsp;Easy
#
# C. Python<br>
# &emsp;&nbsp;Easy!
#
# D. Python<br>
# &emsp;&nbsp;Easy<br>
# &emsp;&nbsp;!
#
# **8. Which string method checks if a string begins with a specific word?**
# A. .beginswith()
# B. .startswith()
# C. .find()
# D. .first()
#
# **9. How do you correctly format a variable price = 10.5 to show exactly 2 decimal places in an f-string?**
# A. `f"Price: {price:.2f}"`
# B. `f"Price: {price:2f}"`
# C. `f"Price: {price.2f}"`
# D. `f"Price: {price}%"`
#
# **10. What is the output of "Py" * 3?**
# A. Py3
# B. Py Py Py
# C. PyPyPy
# D. Error (Cannot multiply strings)
#
# **11. What does the .replace() method do?**
# A. Deletes a specific word from a string.
# B. Swaps two variables' values.
# C. Replaces a specified phrase with another specified phrase.
# D. Reverses the order of characters in a string.
#
# **12. How do you create a hyperlink (URL) in a Markdown cell?**
# A. `(Google)[https://www.google.com]`
# B. `<a href="https://www.google.com">Google</a>`
# C. `[Google](https://www.google.com)`
# D. `link:https://www.google.com`
#
# **13. What is the correct Markdown syntax to display an image?**
# A. `![Alt text](image_url)`
# B. `[Alt text](image_url)`
# C. `!{Alt text}[image_url]`
# D. `*image_url*`

# %% [markdown]
# **Write your answer here:**
# 1.  C
# 2.  C
# 3.  B
# 4.  D
# 5.  B
# 6.  C
# 7.  C and A
# 8.  B
# 9.  A. f"Price: {price:.2f}"
# - colon (:) trigger format mode
# - dot (.) separate fractional part
# - 2/3/4 how many digits
# - f: float
# 10. C
# 11. C
# 12. C
# 13. A

# %% [markdown]
# #**II. Complete Python Code**

# %% [markdown]
# **Question 1**
#
# - Create a variable `student_name` storing the string `"Alice"`.
#
# - Create a variable `gpa` storing the float `3.85`.
#
# - Create a variable `is_enrolled` storing the boolean `True`.
#
# - Cast `gpa` into an integer and save it in a new variable `gpa_int`.
#
# - Cast `is_enrolled` into a string and save it in a new variable `enroll_str`.
#
# - Use a single `print()` to output `student_name, gpa_int, and enroll_str` separated by a dash (-) using the sep parameter.

# %%
student_name="Alice"
gpa=3.85
is_erolled=True
gpa_int=int(gpa)
enroll_str= str(is_erolled)
print(student_name, gpa_int, enroll_str, sep="-")

# %% [markdown]
# **Question 2**
# Given: `text = "  Learning Python is FUN!  "`
#
# - Remove the extra spaces at the beginning and end, and save it to `clean_text`.
#
# - Print `clean_text` in all lowercase letters.
#
# - Print `clean_text` in Title Case (first letter of each word capitalized).
#
# - Print a boolean checking if `clean_text` starts with `"Learning"`.
#
# - Replace `"FUN"` with `"AWESOME"` in `clean_text` and print the result.
#
# - Print a boolean checking if `clean_text` ends with the character `"!"`.
#
# - Print the total length (number of characters) of `clean_text`.

# %%
text = "  Learning Python is FUN!  "
clean_text=text.strip()
print(clean_text.lower())
print(clean_text.title())
print(clean_text.startswith("Learning"))
print(clean_text.replace("FUN","AWESOME"))
print(clean_text.endswith("!"))
print(len(clean_text))

# %% [markdown]
# **Question 3**
#
# - Prompt the user with `"Enter first float: "` and store it as a float `num1`.
#
# - Prompt the user with `"Enter second float: " `and store it as a float `num2`.
#
# - Calculate and print the addition of `num1` and `num2`.
#
# - Calculate and print the floor division (//) of `num1` by `num2`.
#
# - Calculate and print the remainder (modulo) when `num1` is divided by `num2`.
#
# - Calculate `num1` divided by `num2`, round the result to exactly 3 decimal places using the round() function, and print it.

# %%
num1= float(input("Enter first float: "))
num2= float(input("Enter second float: "))
print ("addition: ",num1 + num2)
print("floor division: ", num1//num2)
print("remainder: ", num1%num2)
print("rounded division: ", round(num1/num2,3))

# %% [markdown]
# #***round (var, decimal place)***
# round 3.8 => 4
# int(3.8)=3

# %% [markdown]
# **Question 4**
#
# - Prompt the user for a `city` (string).
#
# - Prompt the user for a `temperature` (float).
#
# - Print `"City: [city]"` using an f-string, ensuring the city name is printed in UPPERCASE.
#
# - Print` "Temp: [temperature]"` using an f-string, ensuring the temperature shows exactly 1 decimal place.
#
# - Without using `.replace()`, print the `city` 3 times on the same line, separated by `"***"` (Hint: Use print() parameters).

# %%
city=input("City: ")
temp=float(input("Temperature: "))
print(f"City: {city.upper()}")
print(f"Temp: {temp:0.1f}")
print(city, city, city, sep="***")

# %% [markdown]
# **Question 5**
#
# - Prompt the user to input an `item_name`.
#
# - Prompt the user to input a `price` as `float`.
#
# - Prompt the user to input a `quantity` as `integer`.
#
# - Calculate the `total_cost = price * quantity`.
#
# - Print a top border using exactly 45 equal signs (=) using string multiplication.
#
# - Print a header row: `"Item Name", "Price", "Qty", and "Total"` separated by spaces or tabs to form columns.
#
# - Print a separator line using exactly 45 dashes (-).
#
# - Print the user's inputted data under the respective headers using an f-string.
#
# - `price` and `total_cost` must display exactly 2 decimal places.
#
# - Print a bottom border using exactly 45 equal signs (=).

# %%
item_name= input("item name: ")
price= float(input("price: "))
quantity= int(input("quantity: "))
total_cost= price*quantity
print("="*45)
print("Item Name", "Price", "Qty", "Total", sep="\t")
print("-"*45)
print(f"{item_name}\t{price:.2f}\t{quantity}\t{total_cost:.2f}")
print("="*45)

# \t -tab tự động nhảy đến các điểm stop mặc định nên có thể tự căn thẳng hàng
# or dùng :<10 (10/15/20)
- colon : trigger format Code
- < left alignment
- > right
- ^ center
- 10: at least 10 character spaces

# %% [markdown]
# #

# %%
item_name= input("item name: ")
price= float(input("price: "))
quantity= int(input("quantity: "))
total_cost= price*quantity
print("="*45)
print("Item Name", "Price", "Qty", "Total", sep="\t")
print("-"*45)
print(f"{item_name:<15}{price:<5.2f}\t{quantity:<5}\t{total_cost:<15.2f}")
print("="*45)
