# %% [markdown]
# #**Complete Python Code**

# %% [markdown]
# **Question 1.**
#
#  1. Using list comprehension, write a single line of code to create a list named `squares_div3`. This list should contain the squares ($x^2$) of all numbers from 1 to 100,000 (inclusive) that are strictly divisible by 3.
#  2. Using List Comprehension, convert a list of numbers into 1s (for even numbers) and 0s (for odd numbers). `sensor_data = [14, 27, 8, 35, 99, 42, 0, 11]`.

# %%
squares_div3 = [i**2 for i in range(3, 100000+1,3)]
print (squares_div3)
sensor_data = [14, 27, 8, 35, 99, 42, 0, 11]
sensored_data = [(i%2 == 0)*1 for i in sensor_data]
print (sensored_data)
# Out:
# [9, 36, 81, 144, 225, 324, 441, 576, 729, 900, 1089, 1296, 1521, 1764, 2025, 2304, 2601, 2916, 3249, 3600, 3969, 4356, 4761, 5184, 5625, 6084, 6561, 7056, 7569, 8100, 8649, 9216, 9801, 10404, 11025, 11664, 12321, 12996, 13689, 14400, 15129, 15876, 16641, 17424, 18225, 19044, 19881, 20736, 21609, 22500, 23409, 24336, 25281, 26244, 27225, 28224, 29241, 30276, 31329, 32400, 33489, 34596, 35721, 36864, 38025, 39204, 40401, 41616, 42849, 44100, 45369, 46656, 47961, 49284, 50625, 51984, 53361, 54756, 56169, 57600, 59049, 60516, 62001, 63504, 65025, 66564, 68121, 69696, 71289, 72900, 74529, 76176, 77841, 79524, 81225, 82944, 84681, 86436, 88209, 90000, 91809, 93636, 95481, 97344, 99225, 101124, 103041, 104976, 106929, 108900, 110889, 112896, 114921, 116964, 119025, 121104, 123201, 125316, 127449, 129600, 131769, 133956, 136161, 138384, 140625, 142884, 145161, 147456, 149769, 152100, 154449, 156816, 159201, 161604, 164025, 166464, 168921, 171396, 173889, 176400, 178929, 181476, 184041, 18662
# ...

# %% [markdown]
# **Question 2.**
#
# Given a matrix (a list of sublists) representing the students' scores in a class.
# Each sublist represents a student's scores for different subjects.
# ```
# students = [
#     'John Smith', 'Emily Johnson', 'Michael Williams', 'Jessica Brown',
#     'David Jones', 'Sophia Davis', 'Daniel Martinez', 'Olivia Miller',
#     'James Wilson', 'Emma Taylor'
# ]
#
# scores = [
#     [85, 78, 92, 88, 76, 90, 87, 89],
#     [92, 86, 78, 94, 89, 91, 85, 82],
#     [75, 80, 88, 84, 79, 92, 86, 90],
#     [89, 92, 75, 81, 87, 79, 84, 88],
#     [78, 81, 89, 93, 85, 90, 88, 82],
#     [92, 85, 78, 90, 83, 89, 87, 91],
#     [86, 91, 75, 80, 88, 84, 82, 89],
#     [78, 84, 89, 92, 86, 91, 83, 80],
#     [90, 88, 82, 79, 91, 76, 83, 85],
#     [87, 80, 91, 85, 78, 92, 89, 84]
# ]
# ```
# Generate a simple statistical report for every student in the class (maximum score, minimum score, avarage score).
# **Constraint:** Do NOT use the built-in max(), min(), or sum() functions on the score lists. You must determine these values by utilizing List methods.
# - Use a for loop to iterate through the students list and the scores matrix simultaneously.
# - Print an f-string for each student in this exact format:
# "John Smith: Max = 92, Min = 76, Average = 85.625"

# %%
students = [
    'John Smith', 'Emily Johnson', 'Michael Williams', 'Jessica Brown',
    'David Jones', 'Sophia Davis', 'Daniel Martinez', 'Olivia Miller',
    'James Wilson', 'Emma Taylor'
]

scores = [
    [85, 78, 92, 88, 76, 90, 87, 89],
    [92, 86, 78, 94, 89, 91, 85, 82],
    [75, 80, 88, 84, 79, 92, 86, 90],
    [89, 92, 75, 81, 87, 79, 84, 88],
    [78, 81, 89, 93, 85, 90, 88, 82],
    [92, 85, 78, 90, 83, 89, 87, 91],
    [86, 91, 75, 80, 88, 84, 82, 89],
    [78, 84, 89, 92, 86, 91, 83, 80],
    [90, 88, 82, 79, 91, 76, 83, 85],
    [87, 80, 91, 85, 78, 92, 89, 84]
]
for i in range(len(students)):
  student=students[i]
  score=scores[i]
  temp_score=sorted(score)
  mins=temp_score[0]
  maxs=temp_score[-1]
  total=0
  for score1 in temp_score:
    total += score1
  average=total/len(temp_score)
  print(f'{student}: Max={maxs} Min={mins} Average={average}')
# Out:
# John Smith: Max=92 Min=76 Average=85.625
# Emily Johnson: Max=94 Min=78 Average=87.125
# Michael Williams: Max=92 Min=75 Average=84.25
# Jessica Brown: Max=92 Min=75 Average=84.375
# David Jones: Max=93 Min=78 Average=85.75
# Sophia Davis: Max=92 Min=78 Average=86.875
# Daniel Martinez: Max=91 Min=75 Average=84.375
# Olivia Miller: Max=92 Min=78 Average=85.375
# James Wilson: Max=91 Min=76 Average=84.25
# Emma Taylor: Max=92 Min=78 Average=85.75

# %%
#Zip
students = [
    'John Smith', 'Emily Johnson', 'Michael Williams', 'Jessica Brown',
    'David Jones', 'Sophia Davis', 'Daniel Martinez', 'Olivia Miller',
    'James Wilson', 'Emma Taylor'
]

scores = [
    [85, 78, 92, 88, 76, 90, 87, 89],
    [92, 86, 78, 94, 89, 91, 85, 82],
    [75, 80, 88, 84, 79, 92, 86, 90],
    [89, 92, 75, 81, 87, 79, 84, 88],
    [78, 81, 89, 93, 85, 90, 88, 82],
    [92, 85, 78, 90, 83, 89, 87, 91],
    [86, 91, 75, 80, 88, 84, 82, 89],
    [78, 84, 89, 92, 86, 91, 83, 80],
    [90, 88, 82, 79, 91, 76, 83, 85],
    [87, 80, 91, 85, 78, 92, 89, 84]
]
for student, score in zip(students, scores):
  temp_score=sorted(score)
  mins=temp_score[0]
  maxs=temp_score[-1]
  total=0
  for score1 in temp_score:
    total += score1
  average=total/len(temp_score)
  print(f'{student}: Max={maxs} Min={mins} Average={average}')
# Out:
# John Smith: Max=92 Min=76 Average=85.625
# Emily Johnson: Max=94 Min=78 Average=87.125
# Michael Williams: Max=92 Min=75 Average=84.25
# Jessica Brown: Max=92 Min=75 Average=84.375
# David Jones: Max=93 Min=78 Average=85.75
# Sophia Davis: Max=92 Min=78 Average=86.875
# Daniel Martinez: Max=91 Min=75 Average=84.375
# Olivia Miller: Max=92 Min=78 Average=85.375
# James Wilson: Max=91 Min=76 Average=84.25
# Emma Taylor: Max=92 Min=78 Average=85.75

# %% [markdown]
# **Question 3.**
#
# You are managing the VIP guest list for an exclusive event.
#
# The current list is: `vip_guests = ['Angelina', 'Zendaya', 'Tom', 'Robert', 'Brad', 'Kristen']`
#
# Write a Python script to update the list based on the latest RSVPs. Perform these exact steps sequentially using built-in list methods:
#
# 1. 'Brad' has informed you he cannot attend. Remove him from the list.
# 2. The venue is slightly overbooked. Remove the last person currently on the list and store their name in a variable called `waitlisted_guest`.
# 3. A very important sponsor arrived. Insert 'Elon' at the very beginning of the list.
# 4. Append 'Selena' and 'Justin' to the end of the list.
# 5. Sort the list permanently in alphabetical order.
# 6. Using a for loop, print a personalized welcome message for each guest remaining on the list.
# 7. Print a message stating who was waitlisted using the variable from step 2.

# %%
#Write your code here
vip_guests = ['Angelina', 'Zendaya', 'Tom', 'Robert', 'Brad', 'Kristen']
vip_guests.remove ('Brad')
del vip_guests[-1]
waitlisted_guest = vip_guests.pop()
vip_guests.insert(0,'Elon')
vip_guests.append('Selena')
vip_guests.append('Justin')
vip_guests.sort()
for i in vip_guests:
  print(f"Hello {i}")
print(vip_guests)
# Out:
# Hello Angelina
# Hello Elon
# Hello Justin
# Hello Selena
# Hello Tom
# Hello Zendaya
# ['Angelina', 'Elon', 'Justin', 'Selena', 'Tom', 'Zendaya']

# %% [markdown]
# **Question 4.**
#
# Your task is exporting a list of user email addresses from a web form. However, users typed them carelessly with random spaces and uppercase letters.
#
# `raw_emails = ['  USER1@gmail.com ', 'admin@YahoO.com', '  sUpPOrT@company.com']`
#
# - Using a List Comprehension, create a new list called `clean_emails`.
# - Inside the comprehension, apply the appropriate methods to strip away the blank spaces and convert all characters to lowercase for every email.
# - Print the total number of processed emails.
# - Print the final `clean_emails` list to verify the data is clean.

# %%
#Write your code here
raw_emails = [' USER1@gmail.com ', 'admin@YahoO.com', ' sUpPOrT@company.com']
clean_emails=[r.strip().lower() for r in raw_emails]
print(len(clean_emails))
print(clean_emails)
# Out:
# 3
# ['user1@gmail.com', 'admin@yahoo.com', 'support@company.com']

# %% [markdown]
# **Question 5.**
# You are analyzing the motion of a self-driving car.
#
#  The car records its distance traveled (in meters) every 1 second. `distances = [0, 5, 14, 27, 44, 65, 90]`.
#
# The velocity (derivative of distance with respect to time) at any interval is calculated by the difference between two consecutive distance measurements: $v = \frac{d_{i+1} - d_i}{\Delta t}$. Since $\Delta t = 1$, the velocity is simply $d_{i+1} - d_i$.
#
# - Calculate the velocity for each interval and append it to the velocities list.
# - Print the velocities list, and use the max() function to find and print the highest velocity reached by the car.

# %%
distances = [0, 5, 14, 27, 44, 65, 90]
velocities = []
for i in range(len(distances)-1): #Lấy len(distances)-1 để không bị out of range
  v = distances[i+1] - distances[i]
  velocities.append(v)
print(velocities)
print(f"The highest velocity: {max(velocities)}")
# Out:
# [5, 9, 13, 17, 21, 25]
# The highest velocity: 25

# %% [markdown]
# **Question 6.**
#
# In computer science, polynomials are often represented as a list of coefficients. For example, the polynomial $P(x) = 5x^3 - 2x^2 + 3x + 4$ can be stored as a list `coeffs = [4, 3, -2, 5]`.
#
# Notice the mathematical relationship here: the index of the list perfectly corresponds to the power of $x$ (e.g., the value 4 is at index 0 and represents $4x^0$, the value 5 is at index 3 and represents $5x^3$).
#
# You are given the coefficient list `coeffs = [4, 3, -2, 5]` and a specific value $x = 3$.
# - Write a Python script using a for loop to algebraically evaluate this polynomial at $x = 3$. You must dynamically extract both the coefficient and its corresponding exponent to calculate the value of each term, accumulate them into a total sum, and print the final result.
# (*Hint: Think about how you can access the position/index of an item while looping through a list*).

# %%
coeffs = [4, 3, -2, 5]
x=3
sum=0
for i in range(len(coeffs)): #Pointer i chạy theo index của coeffes
  sum+=coeffs[i]*(x**i) #Lấy từng giá trị trong coeffs * x cơ số mũ i tương ứng
sum
# Out:
# 130

# %% [markdown]
# **Question 7.**
#
# A coding bootcamp runs for 3 days. You are given 3 lists containing the names of students who attended each day, along with a master roster of all enrolled students.
# ```
# day1 = ["Alice", "Bob", "Charlie", "David"]
# day2 = ["Bob", "David", "Eve", "Frank"]
# day3 = ["Alice", "Bob", "David", "George"]
# roster = ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "George"]
# ```
# Write a Python script to calculate the exact number of days each student attended the bootcamp. You must ONLY use List operations and for loops. *Expected output*
# ```text
# --- BOOTCAMP ATTENDANCE REPORT ---
# Student: Alice      | Days Attended: 2
# Student: Bob        | Days Attended: 3
# Student: Charlie    | Days Attended: 1
# Student: David      | Days Attended: 3
# Student: Eve        | Days Attended: 1
# Student: Frank      | Days Attended: 1
# Student: George     | Days Attended: 1

# %%
#Write your code here
day1 = ["Alice", "Bob", "Charlie", "David"]
day2 = ["Bob", "David", "Eve", "Frank"]
day3 = ["Alice", "Bob", "David", "George"]
roster = ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "George"]
total_days=day1+day2+day3
print("--- BOOTCAMP ATTENDANCE REPORT ---")
for i in roster:
  days_attended=total_days.count(i)
  print(f"Student:{i:<10} | Days Attended: {days_attended:^10}")
# Out:
# --- BOOTCAMP ATTENDANCE REPORT ---
# Student:Alice      | Days Attended:     2
# Student:Bob        | Days Attended:     3
# Student:Charlie    | Days Attended:     1
# Student:David      | Days Attended:     3
# Student:Eve        | Days Attended:     1
# Student:Frank      | Days Attended:     1
# Student:George     | Days Attended:     1
