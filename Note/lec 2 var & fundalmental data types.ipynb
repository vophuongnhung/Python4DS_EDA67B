# %%
list("djfhkjlsdk")
# Out:
# ['d', 'j', 'f', 'h', 'k', 'j', 'l', 's', 'd', 'k']

# %%
bool() # return empty string/ 0 -> false; others - true
# Out:
# False

# %%
h= float(input("height in meters: "))
w= float(input("weight in kilos: "))
bmi= w/h**2
print(f"BMI: {bmi}")
# Out:
# BMI: 25.142857142857142

# %%
try: 
    a=int(input("a: "))
    b=int(input("b: "))
    print("division: ", a/b)
except:
    print("you might have inputted invalid num!")
# Out:
# you might have inputted invalid num!

# %%
# using the try and except blocks, use tab to indent where necessary
try:
    ans = float( input("Type a number to add: " ) )
    print( "100 + {} = {}".format(ans, 100 + ans) )
except:
    print("You did not put in a valid number!")
# without try/except print statement would not get hit if error occurs
print("The program did not break!")
# Out:
# 100 + 2.8 = 102.8
# The program did not break!
