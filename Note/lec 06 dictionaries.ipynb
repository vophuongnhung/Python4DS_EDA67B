# %% [markdown]
# # 1.6. Dictionaries

# %% [markdown]
# ## Working with Dictionaries
# - use {} , ':' to sep key and value, ',' to sep key-value pairs
# - key in dict as index in list
# - use key to access its value

# %%
scores = {'Lan': 9, 'Mai':10, 'Hoa':7, 'Minh':4}

# %%
scores["Lan"]
# Out:
# 9

# %%
scores["Lan"] = 9.5
scores
# Out:
# {'Lan': 9.5, 'Mai': 10, 'Hoa': 7, 'Minh': 4}

# %%
scores ["Hung"] = 9.5 
scores
# Out:
# {'Lan': 9.5, 'Mai': 10, 'Hoa': 7, 'Minh': 4, 'Hung': 9.5}

# %%
# dict phan biet key - trung key lấy value sau 
{'Lan': 9.5, 'Mai': 10, 'Hoa': 7, 'Minh': 4, 'Hung': 9.5, 'Mai':8.5}
# Out:
# {'Lan': 9.5, 'Mai': 8.5, 'Hoa': 7, 'Minh': 4, 'Hung': 9.5}

# %%
{'Lan': 9.5, 'Mai': 10, 'Hoa': 7, 'Minh': 4, 'Hung': 9.5, ('Mai','Minh'):8.5}
# Out:
# {'Lan': 9.5, 'Mai': 10, 'Hoa': 7, 'Minh': 4, 'Hung': 9.5, ('Mai', 'Minh'): 8.5}

# %%
{'Lan': 9.5, 'Mai': 10, 'Hoa': [7,9]}
# Out:
# {'Lan': 9.5, 'Mai': 10, 'Hoa': [7, 9]}

# %%
scores={'Lan': 9.5, 'Mai': 10, 'Hoa': 7, 'Minh': 4}
scores.popitem()
scores
# Out:
# {'Lan': 9.5, 'Mai': 10, 'Hoa': 7}

# %%
scores.get("Minh", 'the key is not available')
# Out:
# 'the key is not available'

# %%
del scores['Hung']
scores
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 del scores['Hung']
#       2 scores
#
# KeyError: 'Hung'

# %%
scores={'Lan': 9.5, 'Mai': 10, 'Hoa': 7, 'Minh': 4}
scores.pop('Minh')
scores
# Out:
# {'Lan': 9.5, 'Mai': 10, 'Hoa': 7}

# %%
scores={'Lan': 9.5, 'Mai': 10, 'Hoa': 7, 'Minh': 4}
scores.clear()
scores
# Out:
# {}

# %%
scores
# Out:
# {'Lan': 9.5, 'Mai': 10, 'Hoa': 7}

# %%
scores.items() # bien dict thanh list cac tuple
# Out:
# dict_items([('Lan', 9.5), ('Mai', 10), ('Hoa', 7)])

# %%
fre = [('Lan', 9.5), ('Mai', 10), ('Hoa', 7)]
type(fre)
# Out:
# list

# %%
dict(fre)
# Out:
# {'Lan': 9.5, 'Mai': 10, 'Hoa': 7}

# %%
scores.keys()
# Out:
# dict_keys(['Lan', 'Mai', 'Hoa'])

# %%
scores.values()
# Out:
# dict_values([9.5, 10, 7])

# %%
list (zip(scores.keys(), scores.values()))
# Out:
# [('Lan', 9.5), ('Mai', 10), ('Hoa', 7)]

# %%
for key in scores.keys():
# for key in scores: - nhu nhau vi hieu la lap tren key
    print(key, scores[key])
# Out:
# Lan 9.5
# Mai 10
# Hoa 7

# %%
'Lan' in scores.keys()
# Out:
# True

# %%
'Lan' in scores
# Out:
# False

# %%
10 in scores
# Out:
# False

# %%
for val in scores.values():
    print(val) # k the lay lai key
# Out:
# 9.5
# 10
# 7

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
text= """The Zen of Python, by Tim Peters

Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!"""

# %%
text_norm= text.lower()
special_chars= {',', '.', '*', '-', ':', '!'}
for char in special_chars:
    text_norm = text_norm.replace(char, ' ')
words = text_norm.split()
unique_words = set(words)
fre_words = {} #dict
for w in unique_words:
    if w in fre_words:
        fre_words[w]+=1
    else: 
        fre_words[w]=1
fre_words
# Out:
# {'although': 1,
#  'idea': 1,
#  'pass': 1,
#  'nested': 1,
#  'never': 1,
#  'first': 1,
#  'one': 1,
#  'refuse': 1,
#  'that': 1,
#  'cases': 1,
#  'in': 1,
#  'explain': 1,
#  'those': 1,
#  'implementation': 1,
#  'unless': 1,
#  'it': 1,
#  'be': 1,
#  'do': 1,
#  'zen': 1,
#  'counts': 1,
#  'bad': 1,
#  'sparse': 1,
#  'guess': 1,
#  'ugly': 1,
#  'explicit': 1,
#  'beats': 1,
#  'special': 1,
#  "it's": 1,
#  'purity': 1,
#  'and': 1,
#  'way': 1,
#  'peters': 1,
#  'explicitly': 1,
#  'temptation': 1,
#  'of': 1,
#  'dutch': 1,
#  'there': 1,
#  'implicit': 1,
#  'not': 1,
#  'practicality': 1,
#  'python': 1,
#  'simple': 1,
#  'at': 1,
#  'the': 1,
#  'good': 1,
#  'only': 1,
#  'by': 1,
#  "you're": 1,
#  'a': 1,
#  'now': 1,
#  'are': 1,
#  'namespaces': 1,
#  'obvious': 1,
#  'break': 1,
#  'is': 1,
#  "aren't": 1,
#  'tim': 1,
#  'flat': 1,
#  'silently': 1,
#  'beautiful': 1,
#  'silenced': 1,
#  'errors': 1,
#  'if': 1,
#  'ambiguity': 1,
#  'than': 1,
# ...

# %% [markdown]
# **6-1. Person:** Use a dictionary to store information about a person you know.
# Store their first name, last name, age, and the city in which they live. You
# should have keys such as first_name, last_name, age, and city. Print each
# piece of information stored in your dictionary.

# %%
person = {'first_name': 'Suon', 'last_name' : 'Beo', 'age':4, 'city': 'Ha Noi'}
print(person['first_name'])
print(person['last_name'])
print(person['age'])
print(person['city'])
# Out:
# Suon
# Beo
# 4
# Ha Noi

# %% [markdown]
# **6-2. Favorite Numbers:** Use a dictionary to store people’s favorite numbers.
# Think of five names, and use them as keys in your dictionary. Think of a favorite
# number for each person, and store each as a value in your dictionary. Print
# each person’s name and their favorite number. For even more fun, poll a few
# friends and get some actual data for your program.

# %%
fav_nums = {'Ngan':6, 'Ha': 7, 'Trang': 37, 'Nhung': 0, 'Minh': 51}
for name, number in fav_nums.items():
    print(name, number)
# Out:
# Ngan 6
# Ha 7
# Trang 37
# Nhung 0
# Minh 51

# %% [markdown]
# **6-3. Glossary:** A Python dictionary can be used to model an actual dictionary.
# However, to avoid confusion, let’s call it a glossary.
# -	Think of five programming words you’ve learned about in the previous
# chapters. Use these words as the keys in your glossary, and store their
# meanings as values.
# -	Print each word and its meaning as neatly formatted output. You might
# print the word followed by a colon and then its meaning, or print the word
# on one line and then print its meaning indented on a second line. Use the
# newline character (\n) to insert a blank line between each word-meaning
# pair in your output
